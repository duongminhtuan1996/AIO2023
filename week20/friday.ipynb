# %%
from collections import defaultdict
import math
import numpy as np
import pandas as pd

# %%
class TreeBooster():

    def __init__(self, X, g, h, params, max_depth, idxs=None):
        self.params = params
        self.max_depth = max_depth
        assert self.max_depth >=0, "max_depth must be nonnegative"
        self.min_child_weight = params['min_child_weight']\
            if params['min_child_weigth'] else 1.0
        self.reg_lambda = params['reg_lambda'] if params['reg_lambda'] else 1.0
        self.gamma = params['gamma'] if params['gamma'] else 0.0
        self.colsample_bynode = params['colsample_bynode'] if params['colsample_bynone'] else 1.0
        if isinstance(g, pd.Series): g = g.values
        if isinstance(h, pd.Series): h = h.values
        if idxs is None: idxs = np.arange(len(g))
        self.X, self.g, self.h, self.idxs = X, g, h, idxs
        self.n, self.c = len(idxs), X.shape[1]
        self.value = -g[idxs].sum() / (h[idxs].sum() + self.reg_lambda) #Eq
        self.best_score_so_far = 0
        if self.max_depth > 0:
            self._maybe_insert_child_nodes()

    def _maybe_insert_child_nodes(self):
        for i in range(self.c): self._find_better_split(i)
        if self.is_leaf: return 
        x = self.X.values[self.idxs, self.split_feature_idx]
        left_idx = np.nonzero(x <= self.threshold)[0]
        right_idx = np.nonzero(x > self.threshold)[0]
        self.left = TreeBooster(self.X, self.g, self.h, self.params, self.max_depth - 1, self.idxs[left_idx])
        self.right = TreeBooster(self.X, self.g, self.h, self.params, self.max_depth - 1, self.idxs[right_idx])

    
    @property
    def is_leaf(self):
        return self.best_score_so_far == 0
    
    def _find_better_split(self, feature_idx):
        x = self.X.values[self.idxs, feature_idx]
        g, h = self.g[self.idxs], self.h[self.idxs]
        sort_idx = np.argsort(x)
        sort_g, sort_h, sort_x = g[sort_idx], h[sort_idx], x[sort_idx]
        sum_g, sum_h = g.sum(), h.sum()
        sum_g_right, sum_h_right = sum_g, sum_h
        sum_g_left, sum_h_left = 0., 0.

        for i in range(0, self.n - 1):
            g_i, h_i, x_i, x_i_next = sort_g[i], sort_h[i], sort_x[i], sort_x[i+1]
            sum_g_left += g_i; sum_g_right -= g_i
            sum_h_left += h_i; sum_h_right -= h_i
            if sum_h_left < self.min_child_weight or x_i == x_i_next: continue
            if sum_h_right < self.min_child_weight: break

            gain = 0.5 * ((sum_g_left**2 / (sum_h_left + self.reg_lambda)) 
                          + (sum_g_right**2 / (sum_h_right + self.reg_lambda))
                          - (sum_g**2 / (sum_h + self.reg_lambda))) - self.gamma/2 #Eq(7) in the xgboost paper
            
            if gain > self.best_score_so_far:
                self.split_feature_idx = feature_idx
                self.best_score_so_far = gain
                self.threshold = (x_i + x_i_next) / 2

        
    def predict(self, X):
        return np.array([self._predict_row(row) for i, row in X.iterrows()])
    
    def _predict_row(self, row):
        if self.is_leaf:
            return self.value
        child = self.left if row[self.split_feature_idx] <= self.threshold\
        else self.right
        return child._predict_row(row)

# %%
class AIVN_XGBoostRegressor():
    """
    XGBoost from Scratch
    """
    def __init__(self, params, random_seed=None):
        self.params = defaultdict(lambda: None, params)
        self.subsample = self.params['subsample']\
            if self.params['subsample'] else 1.0
        self.learning_rate = self.params['learning_rate']\
            if self.params['learning_rate'] else 0.3
        self.base_prediction = self.params['base_score']\
            if self.params['base_score'] else 0.5
        self.max_depth = self.params['max_depth']\
            if self.params['max_depth'] else 5.0
        self.rng = np.random.default_rng(seed=random_seed)

    def fit(self, X, y, objective, num_boost_round, verbose=False):
        current_predictions = self.base_prediction * np.ones(shape=y.shape)
        self.boosters = []
        for i in range(num_boost_round):
            gradients = objective.gradient(y, current_predictions)
            hessians = objective.hessian(y, current_predictions)
            sample_idxs = None if self.subsample == 1.0 \
            else self.rng.choice(len(y),
                                 size=math.floor(self.subsample*len(y)), replace=False)
            booster = TreeBooster(X, gradients, hessians, 
                                  self.params, self.max_depth, sample_idxs)
            current_predictions += self.learning_rate * booster.predict(X)
            self.boosters.append(booster)
            if verbose:
                print(f'[{i}] train loss = {objective.loss(y, current_predictions)}')

    def predict(self, X):
        return (self.base_prediction + self.learning_rate * np.sum([booster.predict(X) for booster in self.boosters], axis=0))

# %%
class SquaredErrorObjective():
    def loss(self, y, pred):
        return np.mean((y - pred)**2)
    
    def gradient(self, y, pred):
        return pred - y
    
    def hessian(self, y, pred):
        return np.ones(len(y))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('advertising.csv')

#X, y
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)

# %%
params = {
    'learning_rate': 0.1, 
    'max_depth': 5,
    'subsample': 0.8,
    'reg_lambda': 1.5,
    'gamma': 0.0,
    'min_child_weight': 25,
    'base_score': 0.0,
    'tree_method': 'exact',
}
num_boost_round = 50

#Train the from-scratch XGBoost model
model_scratch = AIVN_XGBoostRegressor(params, random_seed=42)
model_scratch.fit(X_train, y_train, SquaredErrorObjective(), num_boost_round)

# %%
pred_scratch = model_scratch.predict(X_test)
print(f'Our implementation: {SquaredErrorObjective().loss(y_test, pred_scratch)}')
# Out:
# Our implementation: 1.295246735357908

# %%
from xgboost import XGBRegressor

X = data.iloc[:, :-1]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)

model = XGBRegressor()
model.fit(X_train, y_train)

# pred = model.predict(X_test)
# print(f'Our implementation: {SquaredErrorObjective().loss(y_test, pred)}')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [21], in <cell line: 9>()
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)
#       8 model = XGBRegressor()
# ----> 9 model.fit(X_train, y_train)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\sklearn.py:1014, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1012 with config_context(verbosity=self.verbosity):
#    1013     evals_result: TrainingCallback.EvalsLog = {}
# -> 1014     train_dmatrix, evals = _wrap_evaluation_matrices(
#    1015         missing=self.missing,
#    1016         X=X,
#    1017         y=y,
#    1018         group=None,
#    1019         qid=None,
#    1020         sample_weight=sample_weight,
#    1021         base_margin=base_margin,
#    1022         feature_weights=feature_weights,
#    1023         eval_set=eval_set,
#    1024         sample_weight_eval_set=sample_weight_eval_set,
#    1025         base_margin_eval_set=base_margin_eval_set,
#    1026         eval_group=None,
#    1027         eval_qid=None,
#    1028         create_dmatrix=self._create_dmatrix,
#    1029         enable_categorical=self.enable_categorical,
#    1030         feature_types=self.feature_types,
#    1031     )
#    1032     params = self.get_xgb_params()
#    1034     if callable(self.objective):
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\sklearn.py:934, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     932     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     933         pass
# --> 934 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\core.py:743, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     740     assert self.handle is not None
#     741     return
# --> 743 handle, feature_names, feature_types = dispatch_data_backend(
#     744     data,
#     745     missing=self.missing,
#     746     threads=self.nthread,
#     747     feature_names=feature_names,
#     748     feature_types=feature_types,
#     749     enable_categorical=enable_categorical,
#     750 )
#     751 assert handle is not None
#     752 self.handle = handle
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\data.py:957, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     955     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     956 if _is_pandas_df(data):
# --> 957     return _from_pandas_df(data, enable_categorical, missing, threads,
#     958                            feature_names, feature_types)
#     959 if _is_pandas_series(data):
#     960     return _from_pandas_series(
#     961         data, missing, threads, enable_categorical, feature_names, feature_types
#     962     )
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\data.py:407, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     396 def _from_pandas_df(
#     397     data: DataFrame,
#     398     enable_categorical: bool,
#    (...)
#     402     feature_types: Optional[FeatureTypes],
#     403 ) -> DispatchedDataBackendReturnType:
#     404     data, feature_names, feature_types = _transform_pandas_df(
#     405         data, enable_categorical, feature_names, feature_types
#     406     )
# --> 407     return _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\xgboost\data.py:201, in _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#     195 args = {
#     196     "missing": float(missing),
#     197     "nthread": int(nthread),
#     198 }
#     199 config = bytes(json.dumps(args), "utf-8")
#     200 _check_call(
# --> 201     _LIB.XGDMatrixCreateFromDense(
#     202         _array_interface(data),
#     203         config,
#     204         ctypes.byref(handle),
#     205     )
#     206 )
#     207 return handle, feature_names, feature_types
#
# OSError: exception: access violation reading 0x0000000000000000

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.2.0
# addict                        2.4.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# aiosmtplib                    1.1.7
# aiosqlite                     0.17.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# alabaster                     0.7.12
# alembic                       1.12.0
# altair                        5.0.1
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# asgiref                       3.5.2
# asn1crypto                    1.5.1
# astor                         0.8.1
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-generator               1.10
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     3.0.1
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backoff                       2.2.1
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# banal                         1.0.6
# bar-chart-race                0.1.0
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# blinker                       1.5
# blis                          0.7.11
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# brotlipy                      0.7.0
# build                         1.2.1
# CacheControl                  0.14.0
# cachetools                    4.2.2
# catalogue                     2.0.10
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       3.0.4
# charset-normalizer            2.0.4
# cleo                          2.1.0
# click                         8.0.4
# clip                          1.0
# cloudpathlib                  0.16.0
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.6
# colorcet                      2.0.6
# coloredlogs                   15.0.1
# commonmark                    0.9.1
# comtypes                      1.1.10
# conda                         22.9.0
# conda-build                   3.21.8
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# confection                    0.1.4
# constantly                    15.1.0
# contourpy                     1.1.0
# cookiecutter                  1.7.3
# crashtest                     0.4.1
# cryptography                  3.4.8
# cssselect                     1.1.0
# cvxpy                         1.3.1
# cycler                        0.11.0
# cymem                         2.0.8
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dacite                        1.8.1
# dask                          2022.2.1
# dataset                       1.6.2
# datasets                      2.13.1
# datashader                    0.13.0
# datashape                     0.5.4
# dateutils                     0.6.12
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.6
# distlib                       0.3.8
# distributed                   2022.2.1
# distro                        1.8.0
# Django                        4.1.3
# dlib                          19.24.0
# dnspython                     2.2.1
# docker-pycreds                0.4.0
# docutils                      0.17.1
# duckdb                        0.10.0
# dulwich                       0.21.7
# easydict                      1.10
# ecos                          2.0.12
# email-validator               1.3.0
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# exceptiongroup                1.1.1
# executing                     0.8.3
# faiss-cpu                     1.7.4
# fastapi                       0.88.0
# fastjsonschema                2.19.1
# feedfinder2                   0.0.4
# feedparser                    6.0.11
# filelock                      3.13.3
# filterpy                      1.4.5
# flake8                        3.9.2
# Flask                         2.2.2
# Flask-Cors                    3.0.10
# flatbuffers                   1.12
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# ftfy                          6.1.1
# future                        0.18.2
# gast                          0.4.0
# gdown                         4.5.3
# gensim                        4.1.2
# gitdb                         4.0.10
# GitPython                     3.1.31
# glob2                         0.7
# google-api-core               1.25.1
# google-auth                   2.28.1
# google-auth-oauthlib          0.4.6
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-pasta                  0.2.0
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# googletrans                   4.0.0rc1
# greenlet                      1.1.1
# grpcio                        1.42.0
# gTTS                          2.5.1
# gw_dsl_parser                 0.1.45a6
# h11                           0.9.0
# h2                            3.2.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# hpack                         3.0.0
# hstspreload                   2023.1.1
# htmlmin                       0.1.12
# httpcore                      0.9.1
# httpx                         0.13.3
# huggingface-hub               0.16.4
# humanfriendly                 10.0
# hvplot                        0.7.3
# hyperframe                    5.2.0
# hyperlink                     21.0.0
# idna                          2.10
# imagecodecs                   2021.8.26
# ImageHash                     4.3.1
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib_metadata            7.1.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# installer                     0.7.0
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# iso8601                       1.1.0
# isort                         4.3.21
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jaraco.classes                3.3.1
# jdcal                         1.4.1
# jedi                          0.18.1
# jieba3k                       0.35.1
# Jinja2                        3.1.2
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.4.0
# json5                         0.9.6
# jsonargparse                  4.27.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# kanaries_track                0.0.4
# keras                         2.9.0
# Keras-Preprocessing           1.1.2
# keyring                       24.3.1
# kiwisolver                    1.3.2
# langcodes                     3.3.0
# langdetect                    1.0.9
# lazy_loader                   0.3
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      14.0.6
# libretranslatepy              2.1.1
# librosa                       0.10.1
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# Mako                          1.2.4
# Markdown                      3.3.4
# MarkupSafe                    2.1.1
# matplotlib                    3.6.0
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# menuinst                      1.4.18
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mloader                       1.1.11
# mlxtend                       0.22.0
# mock                          4.0.3
# monotonic                     1.6
# more-itertools                10.2.0
# mpmath                        1.2.1
# msgpack                       1.0.2
# multidict                     5.1.0
# multimethod                   1.9.1
# multipledispatch              0.6.0
# multiprocess                  0.70.14
# munkres                       1.1.4
# murmurhash                    1.0.10
# mypy                          1.9.0
# mypy-extensions               1.0.0
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# newspaper3k                   0.2.8
# nltk                          3.8.1
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.26.4
# numpydoc                      1.2
# oauthlib                      3.2.0
# olefile                       0.46
# onnx                          1.12.0
# onnxruntime                   1.12.1
# onnxsim                       0.4.7
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.8.0.76
# openpyxl                      3.0.9
# opt-einsum                    3.3.0
# osqp                          0.6.2.post8
# outcome                       1.2.0
# packaging                     24.0
# pandas                        1.5.0
# pandas-profiling              3.6.6
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pg8000                        1.23.0
# phik                          0.12.3
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           21.2.4
# pipenv                        2022.9.4
# pkginfo                       1.10.0
# platformdirs                  4.2.0
# plotly                        5.6.0
# pluggy                        1.0.0
# poetry                        1.8.2
# poetry-core                   1.9.0
# poetry-plugin-export          1.7.1
# pooch                         1.8.1
# poyo                          0.5.0
# preshed                       3.0.9
# prometheus-client             0.13.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      5.26.1
# psutil                        5.8.0
# psycopg2                      2.9.2
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# py-cpuinfo                    9.0.0
# py4j                          0.10.9.7
# pyarrow                       12.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.4
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.6
# pycurl                        7.44.1
# pydantic                      1.10.2
# pydeck                        0.8.1b0
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pydotplus                     2.0.2
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# pygame                        2.5.2
# Pygments                      2.11.2
# pygwalker                     0.4.7
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# Pympler                       1.0.1
# PyNaCl                        1.4.0
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.6
# pypdf                         4.2.0
# pypika-tortoise               0.1.6
# pyproject_hooks               1.0.0
# pyreadline                    2.1
# pyreadline3                   3.4.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pyspark                       3.4.1
# pytest                        7.1.1
# python-crfsuite               0.9.9
# python-dateutil               2.8.2
# python-dotenv                 1.0.0
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-multipart              0.0.5
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2021.3
# pytz-deprecation-shim         0.1.0.post0
# pyvi                          0.1.1
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qdldl                         0.1.7
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# rapidfuzz                     3.7.0
# regex                         2022.9.13
# requests                      2.31.0
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# requests-toolbelt             1.0.0
# rfc3986                       1.5.0
# rich                          12.5.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# safetensors                   0.3.1
# scikit-build                  0.16.3
# scikit-image                  0.19.2
# scikit-learn                  1.4.2
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.11.1
# scramp                        1.4.4
# Scrapy                        2.6.1
# scs                           3.2.3
# seaborn                       0.12.0
# segment-analytics-python      2.2.3
# selenium                      4.18.1
# Send2Trash                    1.8.0
# sentence-transformers         2.2.2
# sentencepiece                 0.1.99
# sentry-sdk                    1.45.0
# service-identity              18.1.0
# setproctitle                  1.3.3
# setuptools                    67.6.1
# sgmllib3k                     1.0.0
# shellingham                   1.5.4
# sip                           4.19.13
# six                           1.16.0
# sklearn-crfsuite              0.3.6
# smart-open                    6.4.0
# smmap                         5.0.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# soupsieve                     2.3.1
# soxr                          0.3.7
# spacy                         3.7.2
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.5
# SpeechRecognition             3.10.1
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.29
# sqlglot                       23.7.0
# sqlparse                      0.4.3
# srsly                         2.4.8
# stack-data                    0.2.0
# starlette                     0.22.0
# statsmodels                   0.13.2
# streamlit                     1.24.0
# sympy                         1.10.1
# tables                        3.6.1
# tabula-py                     2.9.0
# tabulate                      0.8.9
# tangled-up-in-unicode         0.2.0
# tb-nightly                    2.11.0a20221018
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# tensorboard                   2.9.1
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.9.1
# tensorflow-estimator          2.9.0
# tensorflow-io-gcs-filesystem  0.27.0
# termcolor                     1.1.0
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# thinc                         8.2.2
# thop                          0.1.1.post2207130030
# threadpoolctl                 3.1.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tinysegmenter                 0.3
# tldextract                    3.2.0
# tokenizers                    0.13.3
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.12.4
# toolz                         0.11.2
# torch                         1.13.0
# torchdata                     0.7.1
# torchinfo                     1.8.0
# torchsummary                  1.5.1
# torchtext                     0.16.1
# torchvision                   0.14.0
# tornado                       6.1
# tortoise-orm                  0.19.2
# tqdm                          4.64.1
# traitlets                     5.1.1
# transformers                  4.31.0
# translate                     3.6.1
# trio                          0.22.0
# trio-websocket                0.10.2
# trove-classifiers             2024.3.25
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typeguard                     2.13.3
# typer                         0.9.0
# typing_extensions             4.10.0
# tzdata                        2022.7
# tzlocal                       4.3.1
# ujson                         5.1.0
# ultralytics                   8.0.227
# underthesea                   1.3.5a3
# underthesea_core              0.0.5a2
# Unidecode                     1.2.0
# urllib3                       2.2.1
# uvicorn                       0.20.0
# validators                    0.20.0
# virtualenv                    20.25.1
# virtualenv-clone              0.5.7
# visions                       0.7.5
# w3lib                         1.21.0
# wandb                         0.16.6
# wasabi                        1.1.2
# wasmtime                      12.0.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# weasel                        0.3.4
# webdriver-manager             3.8.6
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.2.2
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wordcloud                     1.9.2
# wrapt                         1.12.1
# wsproto                       1.2.0
# xarray                        0.20.1
# xgboost                       1.7.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# xxhash                        3.2.0
# yacs                          0.1.8
# yapf                          0.31.0
# yarl                          1.6.3
# ydata-profiling               4.5.1
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0
