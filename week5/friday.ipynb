# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#read a grayscale image and plot it
img = mpimg.imread('nature.jpg')
imgplot = plt.imshow(img, cmap='gray')
plt.show()

# %%
import cv2

#read a grayscale image and plot it
img = cv2.imread('nature.jpg', 0)
imgplot = plt.imshow(img, cmap='gray')
plt.show()

# %%
#read a grayscale image
data = cv2.imread('nature.jpg', 0)

#save the image
cv2.imwrite('nature_1.jpg', data)
# Out:
# True

# %%
import numpy as np
#read a grayscale image (nd.array)
data = cv2.imread('nature.jpg', 0)

#convert from np.array to 2d list
data = data.tolist()
height = len(data)
width = len(data[0])

print(f'Height: {height} - Width: {width}')

#convert from 2d list to np.array
data = np.array(data)

#save the image
cv2.imwrite('nature_2.jpg', data)
# Out:
# Height: 500 - Width: 1200
# True

# %%
import cv2
import numpy as np
height = 800
width = 500

image = [[0]*width for _ in range(height)]

cv2.imwrite('black_nature.jpg', np.array(image))
# Out:
# True

# %%
import cv2 
import numpy as np
import random

height = 800
width = 500

image = [[0]*width for _ in range(height)]

#set noise to each pixel; a random integer in [0, 255]

for i in range(height):
    for j in range(width):
        image[i][j] = random.randint(0, 255)

cv2.imwrite('noise_nature.jpg', np.array(image))
# Out:
# True
