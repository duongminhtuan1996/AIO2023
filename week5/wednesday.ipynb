# %%
import math

def naive_softmax(data):
    exp_data = [math.exp(x) for x in data]
    sum_exp_data = sum(exp_data)
    result = [x/sum_exp_data for x in exp_data]
    return result

# %%
data = [1.0, 2.0, 3.0]
print(naive_softmax(data))
# Out:
# [0.09003057317038046, 0.24472847105479767, 0.6652409557748219]

# %%
data2 = [1000.0, 1001.0, 1002.0]
print(naive_softmax(data2))

# %%
def robust_softmax(data):
    max_value = max(data)
    data = [x-max_value for x in data]

    exp_data = [math.exp(x) for x in data]
    sum_exp_data = sum(exp_data)
    result = [x/sum_exp_data for x in exp_data]
    return result

# %%
data2 = [1000.0, 1001.0, 1002.0]
robust_softmax(data2)
# Out:
# [0.09003057317038046, 0.24472847105479764, 0.6652409557748218]

# %%
data3 = [1.0, 1001.0, 1002.0]
print(robust_softmax(data3))
# Out:
# [0.0, 0.2689414213699951, 0.7310585786300049]

# %%
import matplotlib.pyplot as plt

def gaussian(x, mean, variance):
    part1 = 1 / math.sqrt(2*math.pi*variance)
    part2 = math.exp(-(1/(2*variance)) * (x-mean)**2)
    return part1*part2

# %%
mean = 10
variance = 4

data = list(range(-10, 30+1))
f_data = [gaussian(x, mean, variance) for x in data]

#plot
plt.plot(data, f_data)
plt.show()

# %%
mean = 10
variance = 4

k = 5
data = list(range(-10*k, 30*k+1))
data = [x/k for x in data]

f_data = [gaussian(x, mean, variance) for x in data]

#plot 
plt.plot(data, f_data)
plt.show()

# %%
mean = 10
variance = 4

k = 5
data = list(range(-10*k, 30*k+1))
data = [x/k for x in data]

f_data = [gaussian(x, mean, variance) for x in data]
f_data = [math.log(x) for x in f_data]

plt.plot(data, f_data)
plt.show()

# %%
import math
import matplotlib.pyplot as plt

k = 10
data = list(range(-5*k, 5*k+1))
data = [x/k for x in data]

squared_data = [x**2 +1e-3 for x in data]
plt.plot(data, squared_data)
plt.show()

# %%
log_squared_data = [math.log(x) for x in squared_data]
plt.plot(data, log_squared_data)
plt.show()

# %%
def binary_crossentropy(y, y_hat):
    return -y*math.log(y_hat) - (1-y)*math.log(1-y_hat)

# %%
prediction = [0.3, 0.8, 0.7, 0.4, 0.6, 0.8, 0.9, 0.2]
label = [0, 0, 0, 0, 1, 1, 1, 1]

loss = [binary_crossentropy(y, y_hat) for y, y_hat in zip(label, prediction)]
print(loss)
# Out:
# [0.35667494393873245, 1.6094379124341005, 1.203972804325936, 0.5108256237659907, 0.5108256237659907, 0.2231435513142097, 0.10536051565782628, 1.6094379124341003]

# %%
# (1-p)**gamma

plt.rcParams['figure.autolayout'] = True
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

data = list(range(0, 101))
data = [x/10 for x in data]

f_data = [(1-x)**3 for x in data]
plt.plot(data, f_data, 'c')
plt.show()
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def local_loss_2(y_hat, gamma):
    return -math.log(1-y_hat)*(y_hat**gamma)

data = list(range(1, 100))
data = [x/100 for x in data]

f_data_0 = [local_loss_2(x, 0) for x in data]
f_data_1 = [local_loss_2(x, 1) for x in data]
f_data_2 = [local_loss_2(x, 2) for x in data]
f_data_3 = [local_loss_2(x, 3) for x in data]
f_data_4 = [local_loss_2(x, 4) for x in data]

plt.plot(data, f_data_0, 'r', label='gamma=0')
plt.plot(data, f_data_1, 'g', label='gamma=1')
plt.plot(data, f_data_2, 'b', label='gamma=2')
plt.plot(data, f_data_3, 'c', label='gamma=3')
plt.plot(data, f_data_4, 'k', label='gamma=4')
plt.legend()
plt.show()
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
